# %%
run nick_python.py #include this line so it runs my scripts and import my functions

# %%
sns.pairplot(X)

# %%
plot_residuals(X_train_full, X_holdout, y_train_full, y_holdout) #include this

# %%
visualize_pred_residuals(X_train_full, X_holdout, y_train_full, y_holdout) #include this
# Out:
# 0.8437068199612497
# Training scores: [0.75095097 0.76013908 0.74487593 0.74378819 0.76971599 0.74004708
#  0.76284141 0.74356488 0.75113792 0.76055212]
#
# Testing scores: [0.68425228 0.4656564  0.43559191 0.75078462 0.54292465 0.80128932
#  0.48304338 0.68269018 0.71560156 0.62030945]

# %%
X_train_full = sm.add_constant(X_train_full)
model = sm.OLS(y_train_full, X_train_full)
results = model.fit() #include this
results.summary()
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.594
# Model:                            OLS   Adj. R-squared:                  0.591
# Method:                 Least Squares   F-statistic:                     162.2
# Date:                Fri, 07 Jun 2019   Prob (F-statistic):          5.16e-106
# Time:                        13:29:46   Log-Likelihood:                -371.01
# No. Observations:                 560   AIC:                             754.0
# Df Residuals:                     554   BIC:                             780.0
# Df Model:                           5
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              5.1217      0.277     18.520      0.000       4.579       5.665
# HIVdiagnoses       0.0045      0.001      8.774      0.000       0.004       0.006
# HIVprevalence      0.0018   9.56e-05     18.770      0.000       0.002       0.002
# PLHIV             -0.0002   1.91e-05     -8.917      0.000      -0.000      -0.000
# Population      1.677e-07   8.59e-08      1.952      0.051   -1.03e-09    3.36e-07
# Log_Population    -0.2692      0.024    -11.406      0.000      -0.316      -0.223
# ==============================================================================
# Omnibus:                      100.752   Durbin-Watson:                   2.112
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              452.887
# Skew:                          -0.723   Prob(JB):                     4.54e-99
# Kurtosis:                       7.161   Cond. No.                     1.05e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.05e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_men_pop = X.copy()
X_men_pop["ADULTMEN"] = np.log(hiv_data["ADULTMEN"]) #include this
X_train_men, X_holdout_men, y_train_men, y_holdout_men = train_test_split(X_men_pop, y)

# %%
plot_residuals(X_train_men, X_holdout_men, y_train_men, y_holdout_men) #include this

# %%
visualize_pred_residuals(X_train_men, X_holdout_men, y_train_men, y_holdout_men) #include this
# Out:
# 0.7352270972817542
# Training scores: [0.56574626 0.5945429  0.60283159 0.68700918 0.57401517 0.58919123
#  0.59744851 0.59776721 0.61995892 0.63177394]
#
# Testing scores: [ 0.74102136  0.52287049  0.47576707 -2.77026815 -0.50182035  0.59041984
#   0.4711384   0.44704561 -0.08355209 -1.50636486]

# %%
X_train_men = sm.add_constant(X_train_men) #include this
model = sm.OLS(y_train_men, X_train_men)
results = model.fit()
results.summary()
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.667
# Method:                 Least Squares   F-statistic:                     187.3
# Date:                Fri, 07 Jun 2019   Prob (F-statistic):          1.12e-129
# Time:                        13:29:48   Log-Likelihood:                -320.21
# No. Observations:                 560   AIC:                             654.4
# Df Residuals:                     553   BIC:                             684.7
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              4.3066      0.309     13.925      0.000       3.699       4.914
# HIVdiagnoses       0.0046      0.001      9.143      0.000       0.004       0.006
# HIVprevalence      0.0022   9.36e-05     23.820      0.000       0.002       0.002
# PLHIV             -0.0002   1.89e-05    -11.470      0.000      -0.000      -0.000
# Population      3.866e-07    8.9e-08      4.342      0.000    2.12e-07    5.61e-07
# Log_Population     1.0491      0.257      4.089      0.000       0.545       1.553
# ADULTMEN          -1.3789      0.264     -5.217      0.000      -1.898      -0.860
# ==============================================================================
# Omnibus:                       16.861   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.286
# Skew:                          -0.220   Prob(JB):                     1.19e-06
# Kurtosis:                       3.987   Cond. No.                     1.76e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.76e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_poverty = X.copy() #include me
X_poverty["poverty_rate"] = np.log(hiv_data["poverty_rate"])
X_poverty.drop("Log_Population", axis=1, inplace=True)
X_train_poverty, X_holdout_poverty, y_train_poverty, y_holdout_poverty = train_test_split(X_poverty, y)

# %%
visualize_pred_residuals(X_train_poverty, X_holdout_poverty, y_train_poverty, y_holdout_poverty) #include me
# Out:
# 0.7986724940764599
# Training scores: [0.66810932 0.64139755 0.6442384  0.65427456 0.6441657  0.65928252
#  0.67387253 0.64457413 0.64525823 0.65728836]
#
# Testing scores: [ 0.41045928  0.67296955  0.63597571  0.6065576   0.65643934  0.49681155
#  -0.0810628   0.59391612  0.72245963  0.54007902]

# %%
X_train_poverty = sm.add_constant(X_train_poverty)
model = sm.OLS(y_train_poverty, X_train_poverty)
results = model.fit()
results.summary() #include me
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.574
# Model:                            OLS   Adj. R-squared:                  0.571
# Method:                 Least Squares   F-statistic:                     149.5
# Date:                Fri, 07 Jun 2019   Prob (F-statistic):          2.62e-100
# Time:                        13:30:05   Log-Likelihood:                -370.46
# No. Observations:                 560   AIC:                             752.9
# Df Residuals:                     554   BIC:                             778.9
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.6948      0.143      4.856      0.000       0.414       0.976
# HIVdiagnoses      0.0053      0.001      9.666      0.000       0.004       0.006
# HIVprevalence     0.0015   9.66e-05     16.026      0.000       0.001       0.002
# PLHIV            -0.0002    1.9e-05     -9.239      0.000      -0.000      -0.000
# Population    -2.182e-07   7.78e-08     -2.806      0.005   -3.71e-07   -6.55e-08
# poverty_rate      0.4944      0.052      9.584      0.000       0.393       0.596
# ==============================================================================
# Omnibus:                       36.500   Durbin-Watson:                   2.201
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              140.059
# Skew:                          -0.001   Prob(JB):                     3.86e-31
# Kurtosis:                       5.450   Cond. No.                     5.78e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.78e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_unemployed = X.copy()
X_unemployed["unemployment_rate"] = np.log(hiv_data["unemployment_rate"])
X_unemployed.drop("Log_Population", axis=1, inplace=True)
X_train_unemployed, X_holdout_unemployed, y_train_unemployed, y_holdout_unemployed = train_test_split(X_unemployed, y)

# %%
X_income = X.copy()
X_income["household_income"] = np.log(hiv_data["household_income"])
X_income.drop("Log_Population", axis=1, inplace=True)
X_train_income, X_holdout_income, y_train_income, y_holdout_income = train_test_split(X_income, y)

# %%
visualize_pred_residuals(X_train_unemployed, X_holdout_unemployed, y_train_unemployed, y_holdout_unemployed)
# Out:
# 0.7618837575361711
# Training scores: [0.62654744 0.62240728 0.62280869 0.64032315 0.62787087 0.63216017
#  0.62298071 0.63619937 0.62799487 0.62704659]
#
# Testing scores: [0.61788721 0.66327184 0.54960855 0.29212289 0.61190041 0.48475044
#  0.69491653 0.53817337 0.55192264 0.58214392]

# %%
visualize_pred_residuals(X_train_income, X_holdout_income, y_train_income, y_holdout_income)
# Out:
# 0.7190305214726067
# Training scores: [0.55287195 0.64904892 0.57583982 0.57485481 0.56104924 0.70122582
#  0.5594337  0.55875502 0.55461027 0.55929438]
#
# Testing scores: [ 0.62904615 -3.945541    0.4657425   0.41548337  0.62706921 -2.29009901
#   0.61610144  0.6048181   0.69943966  0.64272493]

# %%
X_train_unemployed = sm.add_constant(X_train_unemployed)
model = sm.OLS(y_train_unemployed, X_train_unemployed)
results = model.fit()
results.summary()
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.539
# Model:                            OLS   Adj. R-squared:                  0.535
# Method:                 Least Squares   F-statistic:                     129.7
# Date:                Fri, 07 Jun 2019   Prob (F-statistic):           7.99e-91
# Time:                        13:29:49   Log-Likelihood:                -417.93
# No. Observations:                 560   AIC:                             847.9
# Df Residuals:                     554   BIC:                             873.8
# Df Model:                           5
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 1.0797      0.163      6.634      0.000       0.760       1.399
# HIVdiagnoses          0.0055      0.001      9.867      0.000       0.004       0.007
# HIVprevalence         0.0017      0.000     16.160      0.000       0.001       0.002
# PLHIV                -0.0002   2.04e-05     -8.985      0.000      -0.000      -0.000
# Population        -2.664e-07   8.41e-08     -3.167      0.002   -4.32e-07   -1.01e-07
# unemployment_rate     0.4224      0.074      5.741      0.000       0.278       0.567
# ==============================================================================
# Omnibus:                       28.447   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.818
# Skew:                          -0.071   Prob(JB):                     2.32e-19
# Kurtosis:                       4.913   Cond. No.                     6.11e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.11e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_train_income = sm.add_constant(X_train_income)
model = sm.OLS(y_train_income, X_train_income)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.666
# Model:                            OLS   Adj. R-squared:                  0.663
# Method:                 Least Squares   F-statistic:                     220.8
# Date:                Fri, 07 Jun 2019   Prob (F-statistic):          2.47e-129
# Time:                        13:29:49   Log-Likelihood:                -310.14
# No. Observations:                 560   AIC:                             632.3
# Df Residuals:                     554   BIC:                             658.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                4.7479      0.229     20.726      0.000       4.298       5.198
# HIVdiagnoses         0.0056      0.001      9.542      0.000       0.004       0.007
# HIVprevalence        0.0022    9.6e-05     22.644      0.000       0.002       0.002
# PLHIV               -0.0002   1.89e-05    -12.688      0.000      -0.000      -0.000
# Population        2.484e-07   9.35e-08      2.658      0.008    6.48e-08    4.32e-07
# household_income    -0.2690      0.022    -12.471      0.000      -0.311      -0.227
# ==============================================================================
# Omnibus:                       23.601   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.576
# Skew:                          -0.351   Prob(JB):                     3.10e-08
# Kurtosis:                       3.994   Cond. No.                     9.37e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.37e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
