# %%
run nick_python.py #include this line so it runs my scripts and import my functions

# %%
sns.pairplot(X)

# %%
plot_residuals(X_train_full, X_holdout, y_train_full, y_holdout) #include this

# %%
visualize_pred_residuals(X_train_full, X_holdout, y_train_full, y_holdout) #include this
# Out:
# 0.772782847135251
# Training scores: [0.67640541 0.60636431 0.60154465 0.63252291 0.602413   0.60759592
#  0.57976537 0.61474101 0.62158276 0.6017408 ]
#
# Testing scores: [-2.71169132  0.53724252  0.5865858   0.21607282  0.64599504  0.59083489
#   0.72688696  0.50455115  0.37989039  0.65114672]

# %%
X_train_full = sm.add_constant(X_train_full)
model = sm.OLS(y_train_full, X_train_full)
results = model.fit() #include this
results.summary()
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.620
# Model:                            OLS   Adj. R-squared:                  0.616
# Method:                 Least Squares   F-statistic:                     180.3
# Date:                Fri, 07 Jun 2019   Prob (F-statistic):          1.28e-113
# Time:                        14:21:58   Log-Likelihood:                -338.36
# No. Observations:                 559   AIC:                             688.7
# Df Residuals:                     553   BIC:                             714.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ...

# %%
X_men_pop = X.copy()
X_men_pop["ADULTMEN"] = np.log(hiv_data["ADULTMEN"]) #include this
X_train_men, X_holdout_men, y_train_men, y_holdout_men = train_test_split(X_men_pop, y)

# %%
plot_residuals(X_train_men, X_holdout_men, y_train_men, y_holdout_men) #include this

# %%
visualize_pred_residuals(X_train_men, X_holdout_men, y_train_men, y_holdout_men) #include this
# Out:
# 0.8019688559412048
# Training scores: [0.70450646 0.70351145 0.71550302 0.70381023 0.7214835  0.72326705
#  0.70100343 0.70355027 0.71535487 0.72102577]
#
# Testing scores: [ 0.7145677   0.71747867  0.57090015  0.71526763  0.35875252  0.32007042
#   0.73091681  0.72778486  0.58576796 -2.01737648]

# %%
X_train_men = sm.add_constant(X_train_men) #include this
model = sm.OLS(y_train_men, X_train_men)
results = model.fit()
results.summary()
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.628
# Model:                            OLS   Adj. R-squared:                  0.624
# Method:                 Least Squares   F-statistic:                     155.3
# Date:                Fri, 07 Jun 2019   Prob (F-statistic):          4.80e-115
# Time:                        14:21:59   Log-Likelihood:                -330.25
# No. Observations:                 559   AIC:                             674.5
# Df Residuals:                     552   BIC:                             704.8
# Df Model:                           6
# Covariance Type:            nonrobust
# ...

# %%
X_poverty = X.copy() #include me
X_poverty["poverty_rate"] = np.log(hiv_data["poverty_rate"])
X_poverty.drop("Log_Population", axis=1, inplace=True)
X_train_poverty, X_holdout_poverty, y_train_poverty, y_holdout_poverty = train_test_split(X_poverty, y)

# %%
visualize_pred_residuals(X_train_poverty, X_holdout_poverty, y_train_poverty, y_holdout_poverty) #include me
# Out:
# 0.7981958214378009
# Training scores: [0.64249615 0.6627579  0.64855479 0.64585393 0.6582101  0.64264138
#  0.65575402 0.64439811 0.638995   0.66376229]
#
# Testing scores: [0.66613926 0.4964928  0.64003799 0.65066886 0.38707252 0.65104764
#  0.56711945 0.65550388 0.67427468 0.20337697]

# %%
X_train_poverty = sm.add_constant(X_train_poverty)
model = sm.OLS(y_train_poverty, X_train_poverty)
results = model.fit()
results.summary() #include me
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.579
# Method:                 Least Squares   F-statistic:                     154.5
# Date:                Fri, 07 Jun 2019   Prob (F-statistic):          1.64e-102
# Time:                        14:22:00   Log-Likelihood:                -361.82
# No. Observations:                 559   AIC:                             735.6
# Df Residuals:                     553   BIC:                             761.6
# Df Model:                           5
# Covariance Type:            nonrobust
# ...

# %%
X_unemployed = X.copy()
X_unemployed["unemployment_rate"] = np.log(hiv_data["unemployment_rate"])
X_unemployed.drop("Log_Population", axis=1, inplace=True)
X_train_unemployed, X_holdout_unemployed, y_train_unemployed, y_holdout_unemployed = train_test_split(X_unemployed, y)

# %%
X_income = X.copy()
X_income["household_income"] = np.log(hiv_data["household_income"])
X_income.drop("Log_Population", axis=1, inplace=True)
X_train_income, X_holdout_income, y_train_income, y_holdout_income = train_test_split(X_income, y)

# %%
visualize_pred_residuals(X_train_unemployed, X_holdout_unemployed, y_train_unemployed, y_holdout_unemployed)
# Out:
# 0.7502646834352705
# Training scores: [0.59947344 0.57887683 0.58532872 0.62713078 0.57601488 0.58338807
#  0.61049496 0.59328448 0.59059043 0.58592737]
#
# Testing scores: [0.50950138 0.66052547 0.59720496 0.08750973 0.64840965 0.75042336
#  0.35485995 0.56279883 0.52192643 0.59982834]

# %%
visualize_pred_residuals(X_train_income, X_holdout_income, y_train_income, y_holdout_income)
# Out:
# 0.7876465581660028
# Training scores: [0.70195871 0.6847093  0.68345112 0.69255089 0.69486977 0.71075867
#  0.70078786 0.66334631 0.75674386 0.69571486]
#
# Testing scores: [ 0.37554839  0.70638809  0.72881675  0.63406704  0.59405441  0.30413439
#   0.31386207  0.86051478 -4.46491418  0.58901775]

# %%
X_train_unemployed = sm.add_constant(X_train_unemployed)
model = sm.OLS(y_train_unemployed, X_train_unemployed)
results = model.fit()
results.summary()
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.539
# Model:                            OLS   Adj. R-squared:                  0.535
# Method:                 Least Squares   F-statistic:                     129.6
# Date:                Fri, 07 Jun 2019   Prob (F-statistic):           1.09e-90
# Time:                        14:22:01   Log-Likelihood:                -397.05
# No. Observations:                 559   AIC:                             806.1
# Df Residuals:                     553   BIC:                             832.1
# Df Model:                           5
# Covariance Type:            nonrobust
# ...

# %%
X_train_income = sm.add_constant(X_train_income)
model = sm.OLS(y_train_income, X_train_income)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.602
# Method:                 Least Squares   F-statistic:                     170.0
# Date:                Fri, 07 Jun 2019   Prob (F-statistic):          2.53e-109
# Time:                        14:22:01   Log-Likelihood:                -342.04
# No. Observations:                 559   AIC:                             696.1
# Df Residuals:                     553   BIC:                             722.0
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
model = sm.OLS(y_train_full, X_train_full)  
results = model.fit_regularized(method='elastic_net', alpha=0.5, L1_wt=0.0)
lin_mod = results.model
fitted = summary.fit()
fitted.outlier_test()['student_resid']

# %%
lin_mod = results.model
fitted = summary.fit()
fitted.outlier_test()['student_resid']
# Out:
# 477     1.298994
# 3006   -0.220415
# 1254    0.195672
# 973     1.027567
# 2335    0.140463
# 1178   -0.152870
# 311     0.570863
# 1921    0.521459
# 2894   -0.573144
# 2929    0.217154
# 2264    0.470646
# 491     1.271717
# 194     1.000057
# 175     1.060817
# 2321    0.454592
# 1441    0.318685
# 1279    0.444101
# 1794    0.598563
# 2507   -1.311215
# 385    -0.013524
# 2257   -1.430837
# 2701    0.385273
# 58     -1.573012
# 507     0.491409
# 2819   -1.271105
# 2143    0.443964
# 413     0.620647
# 359     0.732966
# 1401    0.604627
# 2244    0.897278
#           ...
# 69     -0.827705
# 56     -0.708566
# 727     1.329363
# 139     1.539773
# 1050    0.478273
# 418     1.268546
# 2961   -0.445533
# 240     0.202581
# 2649    0.299678
# 232     0.098297
# 1114    0.829435
# 2935    0.940377
# 608     0.539218
# 1479    1.908598
# 278    -1.597412
# 319     1.213880
# 2681    1.561382
# 1216   -0.354165
# 1460    0.078775
# 343     0.623512
# 2253   -1.544712
# ...

# %%
# Out:
#       student_resid   unadj_p  bonf(p)
# 477        1.298994  0.194488      1.0
# 3006      -0.220415  0.825629      1.0
# 1254       0.195672  0.844939      1.0
# 973        1.027567  0.304604      1.0
# 2335       0.140463  0.888345      1.0
# 1178      -0.152870  0.878556      1.0
# 311        0.570863  0.568325      1.0
# 1921       0.521459  0.602256      1.0
# 2894      -0.573144  0.566781      1.0
# 2929       0.217154  0.828169      1.0
# 2264       0.470646  0.638079      1.0
# 491        1.271717  0.204009      1.0
# 194        1.000057  0.317721      1.0
# 175        1.060817  0.289237      1.0
# 2321       0.454592  0.649581      1.0
# 1441       0.318685  0.750086      1.0
# 1279       0.444101  0.657144      1.0
# 1794       0.598563  0.549710      1.0
# 2507      -1.311215  0.190330      1.0
# 385       -0.013524  0.989214      1.0
# 2257      -1.430837  0.153043      1.0
# 2701       0.385273  0.700183      1.0
# 58        -1.573012  0.116289      1.0
# ...
