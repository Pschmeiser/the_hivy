# %%
run nick_python.py

# %%
sns.pairplot(X)

# %%
plot_residuals(X_train_full, X_holdout, y_train_full, y_holdout)

# %%
visualize_pred_residuals(X_train_full, X_holdout, y_train_full, y_holdout)
# Out:
# 0.7741312990596924
# Training scores: [0.64001847 0.6471308  0.67222396 0.64647439 0.64704668 0.63249957
#  0.6347031  0.63885213 0.63503545 0.65122666]
#
# Testing scores: [ 0.65045927  0.4373299  -0.13099316  0.57911484  0.43813386  0.68800234
#   0.69290525  0.53853673  0.67246532  0.43043365]

# %%
X_train_full = sm.add_constant(X_train_full)
model = sm.OLS(y_train_full, X_train_full)
results = model.fit()#_regularized(method='elastic_net', alpha=0.5, L1_wt=0.0)
results.summary()
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.638
# Model:                            OLS   Adj. R-squared:                  0.635
# Method:                 Least Squares   F-statistic:                     195.1
# Date:                Fri, 07 Jun 2019   Prob (F-statistic):          1.21e-119
# Time:                        12:53:17   Log-Likelihood:                -341.90
# No. Observations:                 560   AIC:                             695.8
# Df Residuals:                     554   BIC:                             721.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              4.7847      0.243     19.703      0.000       4.308       5.262
# HIVdiagnoses       0.0045      0.000     10.572      0.000       0.004       0.005
# HIVprevalence      0.0120      0.002      7.408      0.000       0.009       0.015
# PLHIV             -0.0001   1.76e-05     -8.397      0.000      -0.000      -0.000
# Log_Population    -0.2409      0.020    -12.080      0.000      -0.280      -0.202
# HIVpop/Pop     -1205.1781    190.089     -6.340      0.000   -1578.561    -831.796
# ==============================================================================
# Omnibus:                       54.993   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              195.537
# Skew:                          -0.387   Prob(JB):                     3.47e-43
# Kurtosis:                       5.790   Cond. No.                     4.03e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.03e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_men_pop = X.copy()
X_men_pop["ADULTMEN"] = np.log(hiv_data["ADULTMEN"])
X_train_men, X_holdout_men, y_train_men, y_holdout_men = train_test_split(X_men_pop, y)

# %%
plot_residuals(X_train_men, X_holdout_men, y_train_men, y_holdout_men)

# %%
visualize_pred_residuals(X_train_men, X_holdout_men, y_train_men, y_holdout_men)
# Out:
# 0.823015310971462
# Training scores: [0.71714691 0.70476747 0.69961201 0.70604279 0.69237015 0.71229727
#  0.71290602 0.70370424 0.72713836 0.71356374]
#
# Testing scores: [ 0.44246669  0.70510948  0.74534032  0.66374241  0.79651773  0.6242489
#   0.58443616  0.72739655 -0.59757908  0.60159927]

# %%
X_train_men = sm.add_constant(X_train_men)
model = sm.OLS(y_train_men, X_train_men)
results = model.fit()
results.summary()
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.636
# Model:                            OLS   Adj. R-squared:                  0.632
# Method:                 Least Squares   F-statistic:                     160.8
# Date:                Fri, 07 Jun 2019   Prob (F-statistic):          8.60e-118
# Time:                        12:57:03   Log-Likelihood:                -323.00
# No. Observations:                 560   AIC:                             660.0
# Df Residuals:                     553   BIC:                             690.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              4.9037      0.339     14.456      0.000       4.237       5.570
# HIVdiagnoses       0.0068      0.001     13.454      0.000       0.006       0.008
# HIVprevalence      0.0165      0.002      7.125      0.000       0.012       0.021
# PLHIV             -0.0002   2.09e-05    -11.345      0.000      -0.000      -0.000
# Log_Population    -0.2316      0.314     -0.738      0.461      -0.848       0.385
# HIVpop/Pop     -1739.3794    274.090     -6.346      0.000   -2277.764   -1200.995
# ADULTMEN          -0.0222      0.320     -0.069      0.945      -0.651       0.607
# ==============================================================================
# Omnibus:                       63.297   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              197.689
# Skew:                          -0.515   Prob(JB):                     1.18e-43
# Kurtosis:                       5.722   Cond. No.                     5.42e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.42e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_poverty = X.copy()
X_poverty["poverty_rate"] = np.log(hiv_data["poverty_rate"])
X_poverty.drop("Log_Population", axis=1, inplace=True)
X_train_poverty, X_holdout_poverty, y_train_poverty, y_holdout_poverty = train_test_split(X_poverty, y)

# %%
visualize_pred_residuals(X_train_poverty, X_holdout_poverty, y_train_poverty, y_holdout_poverty)
# Out:
# 0.7157105994090122
# Training scores: [0.55723106 0.54721159 0.63079378 0.5494156  0.54614591 0.55756385
#  0.5515543  0.5499354  0.5582248  0.56877157]
#
# Testing scores: [ 0.54012425  0.61898371 -1.6265817   0.62052734  0.62723864  0.51834347
#   0.59391668  0.62892751  0.52588179  0.31384307]

# %%
X_train_poverty = sm.add_constant(X_train_poverty)
model = sm.OLS(y_train_poverty, X_train_poverty)
results = model.fit()
results.summary()
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     215.9
# Date:                Fri, 07 Jun 2019   Prob (F-statistic):          2.27e-141
# Time:                        13:03:31   Log-Likelihood:                -287.29
# No. Observations:                 560   AIC:                             588.6
# Df Residuals:                     553   BIC:                             618.9
# Df Model:                           6
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             3.6359      0.323     11.255      0.000       3.001       4.270
# HIVdiagnoses      0.0067      0.000     13.763      0.000       0.006       0.008
# HIVprevalence     0.0085      0.002      5.209      0.000       0.005       0.012
# PLHIV            -0.0002   2.21e-05    -11.155      0.000      -0.000      -0.000
# HIVpop/Pop     -784.5270    191.810     -4.090      0.000   -1161.293    -407.761
# ADULTMEN         -0.2208      0.022     -9.959      0.000      -0.264      -0.177
# poverty_rate      0.2374      0.051      4.629      0.000       0.137       0.338
# ==============================================================================
# Omnibus:                       25.127   Durbin-Watson:                   2.069
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.532
# Skew:                          -0.265   Prob(JB):                     1.75e-11
# Kurtosis:                       4.357   Cond. No.                     3.01e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.01e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_unemployed = X.copy()
X_unemployed["unemployment_rate"] = np.log(hiv_data["unemployment_rate"])
X_unemployed.drop("Log_Population", axis=1, inplace=True)
X_train_unemployed, X_holdout_unemployed, y_train_unemployed, y_holdout_unemployed = train_test_split(X_unemployed, y)

# %%
X_income = X.copy()
X_income["household_income"] = np.log(hiv_data["household_income"])
X_income.drop("Log_Population", axis=1, inplace=True)
X_train_income, X_holdout_income, y_train_income, y_holdout_income = train_test_split(X_income, y)

# %%
visualize_pred_residuals(X_train_unemployed, X_holdout_unemployed, y_train_unemployed, y_holdout_unemployed)
# Out:
# 0.7369367304151815
# Training scores: [0.54793743 0.55237417 0.55143481 0.56088536 0.57047081 0.54769607
#  0.56884601 0.6004245  0.54159118 0.55515785]
#
# Testing scores: [0.64111786 0.5314786  0.65748652 0.39042942 0.16505801 0.58012704
#  0.44383743 0.16425823 0.61820583 0.56070988]

# %%
visualize_pred_residuals(X_train_income, X_holdout_income, y_train_income, y_holdout_income)
# Out:
# 0.812246856648835
# Training scores: [0.69926467 0.76663794 0.6842321  0.70336225 0.70016231 0.69877135
#  0.70258161 0.68558048 0.6931937  0.69660612]
#
# Testing scores: [ 0.63771812 -5.82470956  0.80486282  0.61283703  0.520582    0.67160218
#   0.62785133  0.75842976  0.73034438  0.68517942]

# %%
X_train_unemployed = sm.add_constant(X_train_unemployed)
model = sm.OLS(y_train_unemployed, X_train_unemployed)
results = model.fit()
results.summary()
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.553
# Model:                            OLS   Adj. R-squared:                  0.549
# Method:                 Least Squares   F-statistic:                     137.0
# Date:                Fri, 07 Jun 2019   Prob (F-statistic):           2.17e-94
# Time:                        13:13:15   Log-Likelihood:                -392.68
# No. Observations:                 560   AIC:                             797.4
# Df Residuals:                     554   BIC:                             823.3
# Df Model:                           5
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 1.1693      0.160      7.293      0.000       0.854       1.484
# HIVdiagnoses          0.0047      0.001      7.267      0.000       0.003       0.006
# HIVprevalence         0.0128      0.002      6.053      0.000       0.009       0.017
# PLHIV                -0.0002   2.76e-05     -7.827      0.000      -0.000      -0.000
# HIVpop/Pop        -1274.8282    246.957     -5.162      0.000   -1759.914    -789.743
# unemployment_rate     0.3252      0.074      4.368      0.000       0.179       0.471
# ==============================================================================
# Omnibus:                       39.123   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              137.995
# Skew:                           0.189   Prob(JB):                     1.08e-30
# Kurtosis:                       5.402   Cond. No.                     3.23e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.23e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_train_income = sm.add_constant(X_train_income)
model = sm.OLS(y_train_income, X_train_income)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.633
# Model:                            OLS   Adj. R-squared:                  0.630
# Method:                 Least Squares   F-statistic:                     191.1
# Date:                Fri, 07 Jun 2019   Prob (F-statistic):          4.43e-118
# Time:                        13:13:15   Log-Likelihood:                -332.18
# No. Observations:                 560   AIC:                             676.4
# Df Residuals:                     554   BIC:                             702.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                4.6019      0.237     19.424      0.000       4.137       5.067
# HIVdiagnoses         0.0056      0.000     11.735      0.000       0.005       0.007
# HIVprevalence        0.0116      0.002      6.632      0.000       0.008       0.015
# PLHIV               -0.0002   2.26e-05     -8.785      0.000      -0.000      -0.000
# HIVpop/Pop       -1172.5841    205.275     -5.712      0.000   -1575.796    -769.373
# household_income    -0.2427      0.021    -11.605      0.000      -0.284      -0.202
# ==============================================================================
# Omnibus:                       61.814   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              208.344
# Skew:                          -0.475   Prob(JB):                     5.74e-46
# Kurtosis:                       5.833   Cond. No.                     3.36e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.36e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
